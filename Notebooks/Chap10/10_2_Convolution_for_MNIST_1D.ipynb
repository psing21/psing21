# %% [markdown]
# <a href="https://colab.research.google.com/github/psing21/psing21/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-o05_9160
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-o05_9160
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=0b377fdc2ed12e7ae4e714e28c9cbc81416acbd382e24012eb54b859c1f98eee
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lcy9yabi/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10

#proff added these-
#C1 = torch.nn.Conv1d(in_channels=D_i, out_channels=15, kernel_size=3, stride=2, padding="valid")
#C2= torch.nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid")
#C3= torch.nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid")


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),

    nn.Flatten(),
    nn.Linear(60, D_o),
)

print(model)
# Out:
# Sequential(
#   (0): Conv1d(1, 15, kernel_size=(3,), stride=(2,), padding=valid)
#   (1): ReLU()
#   (2): Conv1d(15, 15, kernel_size=(3,), stride=(2,), padding=valid)
#   (3): ReLU()
#   (4): Conv1d(15, 15, kernel_size=(3,), stride=(2,), padding=valid)
#   (5): ReLU()
#   (6): Flatten(start_dim=1, end_dim=-1)
#   (7): Linear(in_features=60, out_features=10, bias=True)
# )

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.248157, train error 84.40,  val loss 2.253774, percent error 85.70
# Epoch     1, train loss 1.627450, train error 64.62,  val loss 1.617735, percent error 67.00
# Epoch     2, train loss 1.402405, train error 56.88,  val loss 1.399485, percent error 57.00
# Epoch     3, train loss 1.263448, train error 50.67,  val loss 1.269423, percent error 52.00
# Epoch     4, train loss 1.182727, train error 48.88,  val loss 1.212323, percent error 51.60
# Epoch     5, train loss 1.102697, train error 45.28,  val loss 1.110780, percent error 46.50
# Epoch     6, train loss 1.027536, train error 41.25,  val loss 1.066267, percent error 43.30
# Epoch     7, train loss 0.937185, train error 36.20,  val loss 0.964779, percent error 38.90
# Epoch     8, train loss 0.870573, train error 38.20,  val loss 0.911868, percent error 39.30
# Epoch     9, train loss 0.748561, train error 30.38,  val loss 0.794652, percent error 32.50
# Epoch    10, train loss 0.648380, train error 25.93,  val loss 0.709750, percent error 27.70
# Epoch    11, train loss 0.690366, train error 26.85,  val loss 0.743946, percent error 28.10
# Epoch    12, train loss 0.570246, train error 21.78,  val loss 0.624120, percent error 25.00
# Epoch    13, train loss 0.505606, train error 19.70,  val loss 0.600554, percent error 22.90
# Epoch    14, train loss 0.488297, train error 18.22,  val loss 0.571399, percent error 20.40
# Epoch    15, train loss 0.441256, train error 16.28,  val loss 0.541117, percent error 18.10
# Epoch    16, train loss 0.347721, train error 13.03,  val loss 0.474271, percent error 18.10
# Epoch    17, train loss 0.340361, train error 12.93,  val loss 0.470012, percent error 17.40
# Epoch    18, train loss 0.328497, train error 12.40,  val loss 0.492380, percent error 18.00
# Epoch    19, train loss 0.296816, train error 11.10,  val loss 0.440452, percent error 15.80
# Epoch    20, train loss 0.217798, train error 7.47,  val loss 0.385823, percent error 13.20
# Epoch    21, train loss 0.227379, train error 8.50,  val loss 0.377708, percent error 12.80
# Epoch    22, train loss 0.185149, train error 6.12,  val loss 0.388350, percent error 13.50
# Epoch    23, train loss 0.178435, train error 6.38,  val loss 0.371789, percent error 13.20
# Epoch    24, train loss 0.168089, train error 5.80,  val loss 0.375071, percent error 12.30
# Epoch    25, train loss 0.160116, train error 5.60,  val loss 0.373257, percent error 12.90
# Epoch    26, train loss 0.159625, train error 5.25,  val loss 0.388816, percent error 12.60
# Epoch    27, train loss 0.155679, train error 5.60,  val loss 0.380453, percent error 12.60
# Epoch    28, train loss 0.157927, train error 5.70,  val loss 0.381603, percent error 12.80
# Epoch    29, train loss 0.125964, train error 4.15,  val loss 0.349917, percent error 11.60
# Epoch    30, train loss 0.137525, train error 4.60,  val loss 0.379930, percent error 12.20
# Epoch    31, train loss 0.127056, train error 4.47,  val loss 0.367657, percent error 11.70
# Epoch    32, train loss 0.125828, train error 4.25,  val loss 0.377724, percent error 12.10
# Epoch    33, train loss 0.113451, train error 3.65,  val loss 0.362264, percent error 10.70
# Epoch    34, train loss 0.136278, train error 4.57,  val loss 0.377290, percent error 11.70
# Epoch    35, train loss 0.138099, train error 5.35,  val loss 0.418254, percent error 12.20
# Epoch    36, train loss 0.098493, train error 3.35,  val loss 0.362213, percent error 10.80
# Epoch    37, train loss 0.086978, train error 2.60,  val loss 0.371429, percent error 10.90
# Epoch    38, train loss 0.086463, train error 2.68,  val loss 0.380192, percent error 10.70
# Epoch    39, train loss 0.082015, train error 2.72,  val loss 0.369827, percent error 10.90
# Epoch    40, train loss 0.072578, train error 2.15,  val loss 0.360394, percent error 10.40
# Epoch    41, train loss 0.070408, train error 1.93,  val loss 0.365389, percent error 11.20
# Epoch    42, train loss 0.075808, train error 2.22,  val loss 0.353575, percent error 9.90
# Epoch    43, train loss 0.066153, train error 1.62,  val loss 0.365495, percent error 10.80
# Epoch    44, train loss 0.063677, train error 1.72,  val loss 0.369578, percent error 10.20
# Epoch    45, train loss 0.071018, train error 2.07,  val loss 0.406655, percent error 10.70
# Epoch    46, train loss 0.060366, train error 1.53,  val loss 0.370415, percent error 10.00
# Epoch    47, train loss 0.060548, train error 1.60,  val loss 0.365816, percent error 10.00
# Epoch    48, train loss 0.059289, train error 1.38,  val loss 0.375556, percent error 10.00
# Epoch    49, train loss 0.063579, train error 1.80,  val loss 0.382536, percent error 10.50
# Epoch    50, train loss 0.055541, train error 1.28,  val loss 0.376558, percent error 10.20
# Epoch    51, train loss 0.054829, train error 1.50,  val loss 0.387334, percent error 10.90
# Epoch    52, train loss 0.062734, train error 2.10,  val loss 0.414576, percent error 10.90
# Epoch    53, train loss 0.052951, train error 1.28,  val loss 0.398644, percent error 10.60
# Epoch    54, train loss 0.054014, train error 1.45,  val loss 0.419819, percent error 10.70
# Epoch    55, train loss 0.054450, train error 1.50,  val loss 0.413627, percent error 10.80
# Epoch    56, train loss 0.046951, train error 0.93,  val loss 0.403743, percent error 10.10
# Epoch    57, train loss 0.053287, train error 1.38,  val loss 0.421064, percent error 10.20
# Epoch    58, train loss 0.048784, train error 1.07,  val loss 0.416961, percent error 10.70
# Epoch    59, train loss 0.049479, train error 1.20,  val loss 0.419800, percent error 10.20
# Epoch    60, train loss 0.042470, train error 0.82,  val loss 0.406937, percent error 10.20
# Epoch    61, train loss 0.046212, train error 1.00,  val loss 0.419568, percent error 10.40
# Epoch    62, train loss 0.041098, train error 0.85,  val loss 0.408555, percent error 10.20
# Epoch    63, train loss 0.042371, train error 0.85,  val loss 0.415912, percent error 10.40
# Epoch    64, train loss 0.042452, train error 0.85,  val loss 0.415750, percent error 10.60
# Epoch    65, train loss 0.039733, train error 0.82,  val loss 0.416557, percent error 10.20
# Epoch    66, train loss 0.039857, train error 0.82,  val loss 0.420419, percent error 10.00
# Epoch    67, train loss 0.039381, train error 0.75,  val loss 0.414456, percent error 9.70
# Epoch    68, train loss 0.038731, train error 0.72,  val loss 0.425133, percent error 10.00
# Epoch    69, train loss 0.038566, train error 0.78,  val loss 0.420292, percent error 9.80
# Epoch    70, train loss 0.039625, train error 0.72,  val loss 0.428389, percent error 9.90
# Epoch    71, train loss 0.038594, train error 0.68,  val loss 0.428816, percent error 10.30
# Epoch    72, train loss 0.036654, train error 0.70,  val loss 0.427753, percent error 9.90
# Epoch    73, train loss 0.036984, train error 0.65,  val loss 0.424995, percent error 9.90
# Epoch    74, train loss 0.036245, train error 0.68,  val loss 0.418361, percent error 9.60
# Epoch    75, train loss 0.035936, train error 0.70,  val loss 0.423189, percent error 9.60
# Epoch    76, train loss 0.036596, train error 0.65,  val loss 0.434444, percent error 10.10
# Epoch    77, train loss 0.034863, train error 0.62,  val loss 0.432889, percent error 9.70
# Epoch    78, train loss 0.034919, train error 0.60,  val loss 0.430403, percent error 9.70
# Epoch    79, train loss 0.035263, train error 0.60,  val loss 0.437065, percent error 10.40
# Epoch    80, train loss 0.033883, train error 0.57,  val loss 0.436000, percent error 9.60
# Epoch    81, train loss 0.033489, train error 0.53,  val loss 0.437207, percent error 9.80
# Epoch    82, train loss 0.033157, train error 0.55,  val loss 0.437421, percent error 9.70
# Epoch    83, train loss 0.033023, train error 0.50,  val loss 0.438111, percent error 9.50
# Epoch    84, train loss 0.033081, train error 0.55,  val loss 0.438321, percent error 9.50
# Epoch    85, train loss 0.032733, train error 0.50,  val loss 0.438034, percent error 9.80
# Epoch    86, train loss 0.032965, train error 0.47,  val loss 0.441431, percent error 9.80
# Epoch    87, train loss 0.032391, train error 0.43,  val loss 0.441984, percent error 9.70
# Epoch    88, train loss 0.032251, train error 0.53,  val loss 0.439854, percent error 9.40
# Epoch    89, train loss 0.032200, train error 0.53,  val loss 0.440707, percent error 9.60
# Epoch    90, train loss 0.032393, train error 0.53,  val loss 0.441057, percent error 9.80
# Epoch    91, train loss 0.031938, train error 0.47,  val loss 0.444117, percent error 9.50
# Epoch    92, train loss 0.031684, train error 0.47,  val loss 0.444851, percent error 9.70
# Epoch    93, train loss 0.031458, train error 0.45,  val loss 0.441947, percent error 9.60
# Epoch    94, train loss 0.031352, train error 0.47,  val loss 0.444788, percent error 9.50
# Epoch    95, train loss 0.031619, train error 0.43,  val loss 0.446876, percent error 9.70
# Epoch    96, train loss 0.031319, train error 0.50,  val loss 0.447887, percent error 9.90
# Epoch    97, train loss 0.030877, train error 0.43,  val loss 0.443901, percent error 9.50
# Epoch    98, train loss 0.030681, train error 0.40,  val loss 0.446524, percent error 9.60
# Epoch    99, train loss 0.030876, train error 0.43,  val loss 0.448057, percent error 10.20
